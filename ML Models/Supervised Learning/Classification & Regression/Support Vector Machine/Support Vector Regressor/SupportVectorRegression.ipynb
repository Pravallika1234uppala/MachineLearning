# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallika1234uppala/ML/blob/main/ML%20Models/Supervised%20Learning/Classification%20%26%20Regression/Support%20Vector%20Machine/Support%20Vector%20Regressor/SupportVectorRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SUPPORT VECTOR REGRESSION**

# %%
#tips dataset:
import seaborn as sns

#loading tips from seaborn into df dataframe:
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#dividing into independent and dependent features before encoding
#this is prevent test data leakage to training data.

X = df.drop('total_bill', axis=1)
y = df['total_bill']

# %%
X
# Out:
#       tip     sex smoker   day    time  size
# 0    1.01  Female     No   Sun  Dinner     2
# 1    1.66    Male     No   Sun  Dinner     3
# 2    3.50    Male     No   Sun  Dinner     3
# 3    3.31    Male     No   Sun  Dinner     2
# 4    3.61  Female     No   Sun  Dinner     4
# ..    ...     ...    ...   ...     ...   ...
# 239  5.92    Male     No   Sat  Dinner     3
# 240  2.00  Female    Yes   Sat  Dinner     2
# 241  2.00    Male    Yes   Sat  Dinner     2
# 242  1.75    Male     No   Sat  Dinner     2
# 243  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
y
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
#now splitting training and testing data:
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train
# Out:
#       tip     sex smoker   day    time  size
# 228  2.72    Male     No   Sat  Dinner     2
# 208  2.03    Male    Yes   Sat  Dinner     2
# 96   4.00    Male    Yes   Fri  Dinner     2
# 167  4.50    Male     No   Sun  Dinner     4
# 84   2.03    Male     No  Thur   Lunch     2
# ..    ...     ...    ...   ...     ...   ...
# 106  4.06    Male    Yes   Sat  Dinner     2
# 14   3.02  Female     No   Sun  Dinner     2
# 92   1.00  Female    Yes   Fri  Dinner     2
# 179  3.55    Male    Yes   Sun  Dinner     2
# 102  2.50  Female    Yes   Sat  Dinner     3
#
# [195 rows x 6 columns]

# %%
#feature encoding:
#for 2 categories - label encoding
#for more categories - one hot encoding

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#creating encoder based on features
lben1 = LabelEncoder()
lben2 = LabelEncoder()
lben3 = LabelEncoder()

# %%
#to remove warnings:
import warnings
warnings.filterwarnings('ignore')

# %%
X_train['sex']=lben1.fit_transform(X_train['sex'])
X_train['smoker']=lben2.fit_transform(X_train['smoker'])
X_train['time']=lben3.fit_transform(X_train['time'])

# %%
X_train
# Out:
#       tip  sex  smoker   day  time  size
# 228  2.72    1       0   Sat     0     2
# 208  2.03    1       1   Sat     0     2
# 96   4.00    1       1   Fri     0     2
# 167  4.50    1       0   Sun     0     4
# 84   2.03    1       0  Thur     1     2
# ..    ...  ...     ...   ...   ...   ...
# 106  4.06    1       1   Sat     0     2
# 14   3.02    0       0   Sun     0     2
# 92   1.00    0       1   Fri     0     2
# 179  3.55    1       1   Sun     0     2
# 102  2.50    0       1   Sat     0     3
#
# [195 rows x 6 columns]

# %%
X_test['sex']=lben1.transform(X_test['sex'])
X_test['smoker']=lben2.transform(X_test['smoker'])
X_test['time']=lben3.transform(X_test['time'])

# %%
X_test.head()
# Out:
#       tip  sex  smoker   day  time  size
# 24   3.18    1       0   Sat     0     2
# 6    2.00    1       0   Sun     0     2
# 153  2.00    1       0   Sun     0     4
# 211  5.16    1       1   Sat     0     4
# 198  2.00    0       1  Thur     1     2

# %%
#One hot Encoding(need to also use column transformer)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

#to drop this encoding at first feature. and index where the column to encode is
#remainder to drop (to drop all remaining columns) other than encoded
#remainder to passthrough to leave all the other features.

#giving it as list [3] to transform easily
ct=ColumnTransformer(transformers=[('onehot', OneHotEncoder(drop='first'), [3])],
                                   remainder='passthrough')

# %%
#to apply this colunm transformer to the data
import sys
import numpy as np

#to see the data clearly
np.set_printoptions(threshold=sys.maxsize)

ct.fit_transform(X_train)
# Out:
# array([[ 1.  ,  0.  ,  0.  ,  2.72,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  2.03,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  0.  ,  0.  ,  4.  ,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  4.5 ,  1.  ,  0.  ,  0.  ,  4.  ],
#        [ 0.  ,  0.  ,  1.  ,  2.03,  1.  ,  0.  ,  1.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.51,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  0.  ,  1.  ,  2.  ,  1.  ,  0.  ,  1.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.15,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  1.75,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  2.74,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 1.  ,  0.  ,  0.  ,  3.  ,  1.  ,  1.  ,  0.  ,  3.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.14,  0.  ,  0.  ,  0.  ,  5.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.5 ,  0.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.65,  1.  ,  1.  ,  0.  ,  2.  ],
# ...

# %%
X_train=ct.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.  ,  0.  ,  0.  ,  2.72,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  2.03,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  0.  ,  0.  ,  4.  ,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  4.5 ,  1.  ,  0.  ,  0.  ,  4.  ],
#        [ 0.  ,  0.  ,  1.  ,  2.03,  1.  ,  0.  ,  1.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.51,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  0.  ,  1.  ,  2.  ,  1.  ,  0.  ,  1.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.15,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  1.75,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  2.74,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 1.  ,  0.  ,  0.  ,  3.  ,  1.  ,  1.  ,  0.  ,  3.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.14,  0.  ,  0.  ,  0.  ,  5.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.5 ,  0.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.65,  1.  ,  1.  ,  0.  ,  2.  ],
# ...

# %%
X_test=ct.transform(X_test)

# %%
X_test
# Out:
# array([[1.  , 0.  , 0.  , 3.18, 1.  , 0.  , 0.  , 2.  ],
#        [0.  , 1.  , 0.  , 2.  , 1.  , 0.  , 0.  , 2.  ],
#        [0.  , 1.  , 0.  , 2.  , 1.  , 0.  , 0.  , 4.  ],
#        [1.  , 0.  , 0.  , 5.16, 1.  , 1.  , 0.  , 4.  ],
#        [0.  , 0.  , 1.  , 2.  , 0.  , 1.  , 1.  , 2.  ],
#        [0.  , 1.  , 0.  , 2.  , 1.  , 1.  , 0.  , 2.  ],
#        [0.  , 0.  , 1.  , 2.56, 1.  , 1.  , 1.  , 2.  ],
#        [0.  , 0.  , 1.  , 2.52, 0.  , 0.  , 1.  , 2.  ],
#        [0.  , 1.  , 0.  , 3.23, 1.  , 0.  , 0.  , 2.  ],
#        [0.  , 0.  , 0.  , 3.  , 0.  , 1.  , 0.  , 2.  ],
#        [0.  , 1.  , 0.  , 3.  , 1.  , 0.  , 0.  , 2.  ],
#        [1.  , 0.  , 0.  , 1.47, 1.  , 0.  , 0.  , 2.  ],
#        [0.  , 0.  , 1.  , 1.5 , 0.  , 0.  , 1.  , 2.  ],
#        [0.  , 1.  , 0.  , 2.  , 1.  , 1.  , 0.  , 2.  ],
#        [0.  , 0.  , 1.  , 1.83, 0.  , 0.  , 1.  , 1.  ],
#        [0.  , 0.  , 1.  , 1.36, 0.  , 0.  , 1.  , 3.  ],
# ...

# %%
#SVR-Support Vector Regression:

from sklearn.svm import SVR

svr = SVR()

# %%
svr
# Out:
# SVR()

# %%
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(X_test)

# %%
#error & performance metrics:
from sklearn.metrics import r2_score, mean_absolute_error

print("R2 score:",r2_score(y_pred,y_test))
print("Error:",mean_absolute_error(y_pred,y_test))
# Out:
# R2 score: -1.0206685386617411
# Error: 4.413774883497757

# %%
#hyper parameter tuning

#using grid search cv

from sklearn.model_selection import GridSearchCV

#parameters range:
params = {'C': [0.1, 0.01, 1, 1.10, 10, 100, 1000],
          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
          'kernel': ['rbf']
}

# %%
grid_model = GridSearchCV(svr, param_grid=params, refit=True, verbose=3)

#fitting the grid model with svr as estimator
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.119 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.014 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.017 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.019 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.042 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.013 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.099 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.080 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.080 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.049 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.109 total time=   0.0s
# ...

# %%
grid_model.best_params_
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
prediction_grid = grid_model.predict(X_test)

# %%
#error & performance metrics:
from sklearn.metrics import r2_score, mean_absolute_error

print("R2 score:",r2_score(prediction_grid,y_test))
print("Error:",mean_absolute_error(prediction_grid,y_test))
# Out:
# R2 score: -0.0729513733788345
# Error: 4.129773285984424
